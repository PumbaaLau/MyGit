# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()
data = digits.data

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax1 = fig.add_subplot(221)
# plt.gray()
ax1.matshow(digits.images[0])
plt.show()
# ax2 = fig.add_subplot(222)
# # plt.gray()
# ax2.matshow(digits.images[0])

# ax3 = fig.add_subplot(223)
# plt.gray()
# ax3.imshow(digits.images[0])

# ax4 = fig.add_subplot(224)
# # plt.gray()
# # plt.matshow(digits.images[0])
# plt.show(digits.images[0])

# %%
from sklearn.datasets import load_sample_image

# %%
img = load_sample_image('flower.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)
plt.show()

# %%
plt.matshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-1fd9cf9b40b2> in <module>()
# ----> 1 plt.matshow(img)
#       2 plt.show()
#
# D:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in matshow(A, fignum, **kw)
#    2355         ax  = fig.add_axes([0.15, 0.09, 0.775, 0.775])
#    2356
# -> 2357     im = ax.matshow(A, **kw)
#    2358     sci(im)
#    2359
#
# D:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in matshow(self, Z, **kwargs)
#    7395         """
#    7396         Z = np.asanyarray(Z)
# -> 7397         nr, nc = Z.shape
#    7398         kw = {'origin': 'upper',
#    7399               'interpolation': 'nearest',
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# ## make_classification

# %%
sklearn.datasets.make_classification(n_samples=100, n_features=20, n_informative=2, n_redundant=2,  
                    n_repeated=0, n_classes=2, n_clusters_per_class=2, weights=None,  
                    flip_y=0.01, class_sep=1.0, hypercube=True,shift=0.0, scale=1.0,   
                    shuffle=True, random_state=None)

# %% [markdown]
# - n_samples：样本个数
# - n_features：特征个数 = n_informative + n_redundant + n_repeated
# - n_informative：多信息特征的个数
# - n_redundant：冗余信息，informative特征的随机线性组合
# - n_repeated ：重复信息，随机提取n_informative和n_redundant 特征
# - n_classes：分类类别
# - n_clusters_per_class ：某一个类别是由几个cluster构成的

# %%
import matplotlib.pyplot as plt

from sklearn.datasets import make_classification
from sklearn.datasets import make_blobs
from sklearn.datasets import make_gaussian_quantiles
from sklearn.datasets import make_hastie_10_2

# %%
plt.figure(figsize=(8,8))
plt.subplots_adjust(bottom=.05, top=.9, left=.05, right=.95)
# plt.gray(False)

plt.subplot(421)  
plt.title("One informative feature, one cluster per class", fontsize='small')  
X1, Y1 = make_classification(n_samples=1000,n_features=2, n_redundant=0, n_informative=1,  
                             n_clusters_per_class=1)  
plt.scatter(X1[:, 0], X1[:, 1], marker='o', edgecolors='black', c=Y1)  
  
plt.subplot(422)  
plt.title("Two informative features, one cluster per class", fontsize='small')  
X1, Y1 = make_classification(n_samples=1000,n_features=2, n_redundant=0, n_informative=2,  
                             n_clusters_per_class=1)  
plt.scatter(X1[:, 0], X1[:, 1], marker='o',edgecolors='black', c=Y1)  
  
plt.subplot(423)  
plt.title("Two informative features, two clusters per class", fontsize='small')  
X2, Y2 = make_classification(n_samples=1000,n_features=2, n_redundant=0, n_informative=2)  
plt.scatter(X2[:, 0], X2[:, 1], marker='o',edgecolors='black', c=Y2)  
    
plt.subplot(424)  
plt.title("Multi-class, two informative features, one cluster",  
          fontsize='small')  
X1, Y1 = make_classification(n_samples=1000,n_features=2, n_redundant=0, n_informative=2,  
                             n_clusters_per_class=1, n_classes=3)  
plt.scatter(X1[:, 0], X1[:, 1], marker='o',edgecolors='black', c=Y1)  
  
plt.subplot(425)  
plt.title("Three blobs", fontsize='small')  
X1, Y1 = make_blobs(n_samples=1000,n_features=2, centers=3)  
plt.scatter(X1[:, 0], X1[:, 1], marker='o',edgecolors='black', c=Y1)  

plt.subplot(426)  
plt.title("Gaussian divided into four quantiles", fontsize='small')  
X1, Y1 = make_gaussian_quantiles(n_samples=1000,n_features=2, n_classes=4)  
plt.scatter(X1[:, 0], X1[:, 1], marker='o',edgecolors='black', c=Y1)  
  
plt.subplot(427)  
plt.title("hastie data ", fontsize='small')  
X1, Y1 = make_hastie_10_2(n_samples=1000)  
plt.scatter(X1[:, 0], X1[:, 1], marker='o',edgecolors='black', c=Y1)  
plt.show()

# %% [markdown]
# ## make_circles and make_moons

# %%
from sklearn.datasets import make_circles
from sklearn.datasets import make_moons
import numpy as np

# %%
fig=plt.figure(1)  

x1,y1=make_circles(n_samples=1000,factor=0.5,noise=0.1)  
plt.subplot(121)  
plt.title('make_circles function example', fontsize='small')  
plt.scatter(x1[:,0],x1[:,1],marker='o',edgecolors='black', c=y1)

plt.subplot(122)  
x1,y1=make_moons(n_samples=1000,noise=0.1)  
plt.title('make_moons function example')  
plt.scatter(x1[:,0],x1[:,1],marker='o',edgecolors='black', c=y1)  
plt.show()
